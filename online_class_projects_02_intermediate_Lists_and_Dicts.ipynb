# %% [markdown]
# <a href="https://colab.research.google.com/github/zahidaraees/Project-4-Assignments/blob/main/online_class_projects_02_intermediate_Lists_and_Dicts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
/online_class_projects/02_intermediate/Lists and Dicts

Problem #1: List Practice
In this problem, we will:

Create a list of fruits.

Print the length of the list.

Add "mango" to the end of the list.

Print the updated list.
"""
def main():
    # Create a list that contains the following fruits
    fruit_list = ['apple', 'banana', 'orange', 'grape', 'pineapple']

    # Print length of the list
    print(f"Length of the list: {len(fruit_list)}")
    print (f"Old list before adding item:{fruit_list}")
    # Add 'mango' at the end of the list
    fruit_list.append('mango')

    # Print the updated list

    print(f"Updated fruit list: {fruit_list}")
    print(f"After updation, length of the list: {len(fruit_list)}")

# Calling main function to execute the code, it's a boiler plate of python
if __name__ == "__main__":
    main()
# Out:
# Length of the list: 5
# Old list before adding item:['apple', 'banana', 'orange', 'grape', 'pineapple']
# Updated fruit list: ['apple', 'banana', 'orange', 'grape', 'pineapple', 'mango']
# After updation, length of the list: 6

# %%
"""
Problem #2: Index Game
This problem asks us to create a Python program that will help practice list indexing, slicing, and modifying elements in a list. We need to:

Initialize a list.

Implement functions to access, modify, and slice the list.

Create a text-based game for interaction.

"""
def access_element(my_list, index):
    try:
        return my_list[index]
    except IndexError:
        return "Index out of range"

def modify_element(my_list, index, new_value):
    try:
        my_list[index] = new_value
        return my_list
    except IndexError:
        return "Index out of range"

def slice_list(my_list, start_index, end_index):
    try:
        return my_list[start_index:end_index]
    except IndexError:
        return "Index out of range"

def game():
    my_list = [10, "apple", 3.14, "banana", True]

    print("Welcome to the Index Game!")
    print(f"Your list: {my_list}")

    while True:
        # Display the available operations
        print ("Index Game Application")
        print ("\n**********************")
        print("\nChoose an operation:")
        print("1. Access an element")
        print("2. Modify an element")
        print("3. Slice the list")
        print("4. Quit")

        choice = input("Enter the number of your choice: ")

        if choice == '1':
            index = int(input("Enter the index you want to access: "))
            result = access_element(my_list, index)
            print(f"Result: {result}")

        elif choice == '2':
            index = int(input("Enter the index you want to modify: "))
            new_value = input("Enter the new value: ")
            result = modify_element(my_list, index, new_value)
            print(f"Updated list: {result}")

        elif choice == '3':
            start_index = int(input("Enter the start index: "))
            end_index = int(input("Enter the end index: "))
            result = slice_list(my_list, start_index, end_index)
            print(f"Sliced list: {result}")

        elif choice == '4':
            print("Goodbye!")
            break
        else:
            print("Invalid choice. Please choose a valid operation.")

# Boilerplate to ensure the script runs as main
if __name__ == "__main__":
    game()
# Out:
# Welcome to the Index Game!
# Your list: [10, 'apple', 3.14, 'banana', True]
# Index Game Application
#
# **********************
#
# Choose an operation:
# 1. Access an element
# 2. Modify an element
# 3. Slice the list
# 4. Quit
# Enter the number of your choice: 1
# Enter the index you want to access: 0
# Result: 10
# Index Game Application
#
# **********************
#
# Choose an operation:
# 1. Access an element
# 2. Modify an element
# 3. Slice the list
# 4. Quit
# Enter the number of your choice: 0
# Invalid choice. Please choose a valid operation.
# Index Game Application
#
# **********************
#
# Choose an operation:
# 1. Access an element
# 2. Modify an element
# 3. Slice the list
# 4. Quit
# Enter the number of your choice: 12
# Invalid choice. Please choose a valid operation.
# Index Game Application
#
# **********************
#
# Choose an operation:
# 1. Access an element
# 2. Modify an element
# 3. Slice the list
# 4. Quit
# Enter the number of your choice: 3
# ...
